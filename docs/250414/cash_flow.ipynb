# %% [markdown]
# # Berechnung des Cash Flows

# %%
import pandas as pd

# %%
df = pd.read_csv('ledger.csv', sep=';')

# %%
df.set_index(['Jahr', 'Rechnung', 'level1', 'level2', 'level3'], inplace=True)

# %%
df
# Out:
#                                                                                    Konto  \
# Jahr Rechnung        level1   level2         level3
# 2020 Bilanz          Aktiven  Umlaufvermögen Flüssige Mittel                       Kasse
#                                              Flüssige Mittel                        Post
#                                              Flüssige Mittel                        Bank
#                                              Forderungen                             FLL
#                                              Forderungen                      Delkredere
#                                              Vorräte                               Waren
#                               Anlagevermögen Materielles AV                     Mobilien
#                                              Materielles AV                  WB Mobilien
#                                              Materielles AV                    Immoblien
# ...
