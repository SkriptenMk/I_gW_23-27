# %% [markdown]
# # Python Dictionaries

# %% [markdown]
# ## VIII örtige Eidgenossenschaft
#
# Als erste Übung soll ein Python Dictionary der VIII örtigen
# Eidgenossenschaft erstellt werden. Als Schlüssel dient der Ort, Inhalt
# sind Beitrittsjahr, Hauptort sowie die Information, ob es sich um einen
# Stadt- oder Landort handelt.
#
# Den Bestand der VIII örtigen Eidgenossenschaft kann untenstehender Karte
# entnommen werden.

# %% [markdown]
# <img alt="VIII örtige Eidgenossenschaft" src="data:image/png;base64,..." />

# %% [markdown]
# Die Informationnen zu den Beitrittsjahren können Sie dem [Wikipedia Eintrag zu den acht alten Orten](https://de.wikipedia.org/wiki/Acht_Alte_Orte) entnehmen.

# %%
# Welche Datenstruktur (Liste oder Tupel) soll für die Einträge im Dictionary verwendet werden?

# %% [markdown]
# In der nächsten Zelle sollen die Angaben zu Schwyz abgefragt werden.

# %%
# hier Ihr Code

# %% [markdown]
# ## XIII örtige Eidgenossenschaft
#
# Zwischen 1386 (Schlacht bei Sempach) und 1798 (Beginn der Helvetik) bestand die Eidgenossenschaft aus 13 Orten. Im folgenden soll ein eigener Python Dictionary mit den seit 1386 dazugekommenen zusätzlichen fünf Orten erstell werden.
#
# Welche das sind, kann untenstehender Karte entnommen werden.

# %% [markdown]
# <img alt="XIII örtige Eidgenossenschaft" src="data:image/png;base64,..." />

# %% [markdown]
# Die Angaben zu den Beitrittsjahren finden sich im [Wikipedia Artikel zur XIII örtigen Eidgenossenschaft](https://de.wikipedia.org/wiki/Dreizehn_Alte_Orte).

# %%
# hier Ihr Code

# %% [markdown]
# Die Zusammenführung der beiden Dictionaries zu einem Dictionary `xiii_orte` kann auf drei Arten erfolgen:
#
# * `xiii_orte = viii_orte | neue_orte`
# * `xiii_orte = viii_orte.copy()`
#
#   `xiii_orte.update(neue_orte)`
# * `xiii_orte = {**viii_orte, **neue_orte}`
#
# Die erste Variante wurde extra für das Zusammenführen zweier Dictionaries geschaffen. Die Varianten zwei und drei führen aufgrund der Eigenschaften eines Python Dictionary auch zum Ziel. In Python sind jedoch jene Formulierungen vorzuziehen, welche zur Lösung eines konkreten Problems geschaffen worden sind.

# %%
# hier Ihr Code

# %% [markdown]
# ## Iterieren über die alte Eidgenossenschaft
#
# In der nächsten Zelle soll über die Liste der XIII Orte iteriert werden. Im Rahmen dieser Iteration soll ausgegeben werden, ob es sich um einen Land- oder Stadtort handelt.

# %%
# hier Ihr Code
